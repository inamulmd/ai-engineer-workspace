# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("Hi my name is Inamul and I like banoffee pie")

# %%
tokens
# Out:
# [12194, 922, 1308, 382, 730, 66068, 326, 357, 1299, 9171, 26458, 5148]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 730 =  In
# 66068 = amul
# 326 =  and
# 357 =  I
# 1299 =  like
# 9171 =  ban
# 26458 = offee
# 5148 =  pie

# %%
encoding.decode([326])
# Out:
# ' and'
